# %% [markdown]
# <a href="https://colab.research.google.com/github/shunya-yan/colab/blob/main/Proof_of_Work_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib
import random
import string

def generate_hash(input_str):
        # ハッシュ値を生成
        return hashlib.sha256(input_str.encode()).hexdigest()


def generate_hash_with_condition(str1, str2, num, str3=''):

    # 入力値を文字列に変換
    input_str = f"{str1}{str2}{str3}{num}"
    print(input_str)

    n = 0

    while True:

        n += 1

        # 乱数を生成（ここでは簡単のため、ランダムな文字列を使用）
        random_str = ''.join(random.choices(string.ascii_letters + string.digits, k=10))

        # 乱数を含めた文字列のハッシュ値を取得
        hash_result = generate_hash(input_str + random_str)

        # ハッシュの先頭が'00'かどうかを確認
        if hash_result.startswith('0000'):
            print("OK")
            return hash_result, random_str  # 条件を満たした乱数とハッシュ値を返す
        else:
            print(n,hash_result)
            i=1000
        # 条件を満たさない場合は、ループを続ける

# テスト実行
transaction = "00005aa3392c1a17b4fee469c24ae16659149959fdde5a4bfa9a348a31f2481c"
hash_value, nonce = generate_hash_with_condition("f10230150", "f10230302",  10000, transaction)
print(f'hash:{hash_value}')
print(f'nonce:{nonce}')
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# 268685 7b8fcd0f61e4bb689d9077a8251663f4394e6bae8c76b7fe104e94c4327f9b60
# 268686 e92737838e2d038cb59bf8cb7af841e2ff1614dd3c2cdd9b0e9f3c01780996e2
# 268687 0d61a23067129d0e0760c56cb60f8b5776a09776ac1336f7e57fc874d568674b
# 268688 9a6639a88a7f7d344bf3a4dfb82b246fc68b156fc888b7e510cd7c71ba3c7f9f
# 268689 a509242d7b1d13cd7f7e7b245f8f35fa4edb988eba1242d6b6a9699579b838c2
# 268690 53f37c8253e6c8012b442a4b01cc5ec4ccf5036ad131d65151a5c6eb3d4ba5a1
# 268691 a4fb5c3040004b6ca796a9c1543bd8acebd877ce9ec409288ad97eba952a1d14
# 268692 79a64e14d36491079acb8a7d2d2b04126ac5fec125d30b26124ed58291db7d2e
# 268693 2fd2290fa9c75effa5241673d25dffbaa4b90385ed4f1a7adad72ce739a1122a
# 268694 f3f854dd6575fa5f094d7713a7f993f089c24aa86911b42a3ae136a67fe63eb4
# 268695 950d675dc78e22c70840fad6d4dcb34e0b521b77cc4b49fb08e1322b8f68e0af
# 268696 51f9577059834b97c1b49026297b96c70ffe2bcb564e61748467d8cca18d3399
# 268697 68174a27d0800fab43c5e3d323897f75b90a08465835e40237d78dccb06c6de1
# ...
